# %%
import tensorflow as tf
from tensorflow import keras 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

IMAGE_SIZE=[48,48]

train_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="/root/kaggle-dataset/cat-and-dog/training_set",
    labels='inferred',
    label_mode='categorical',
    image_size=IMAGE_SIZE,
    batch_size=6000,
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="/root/kaggle-dataset/cat-and-dog/test_set",
    labels='inferred',
    label_mode='categorical',
    image_size=IMAGE_SIZE,
)

model = keras.models.Sequential([
    keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(48, 48, 3)),
    keras.layers.MaxPooling2D(2, 2),
    keras.layers.Conv2D(128, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(256, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(512, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),    
    keras.layers.Flatten(),
    keras.layers.Dense(96),
    keras.layers.Dense(2, activation='softmax'),
])

model.summary()

monitor = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=5, 
        verbose=1, mode='auto', restore_best_weights=True)

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy','categorical_crossentropy']
)

train_history = model.fit(train_dataset,
    validation_data=test_dataset,
    callbacks=[monitor],
    verbose=2,
    epochs=100,
    workers=1,
)

#print(test_dataset.element_spec)
#print(tf.data.DatasetSpec.from_value(test_dataset))

history_frame = pd.DataFrame(train_history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot()

class_names = test_dataset.class_names
#print(class_names)

plt.figure(figsize=(10, 10))
for images, labels in test_dataset.take(1):
  for i in range(25):
    ax = plt.subplot(5, 5, i + 1)
    #print(images[i].shape)
    plt.imshow(images[i].numpy().astype("uint8"))
    predict = model.predict(images[i].numpy().reshape([1,48,48,3]))
    #print(predict.shape)
    #plt.title(class_names[tf.math.argmax(labels[i])])
    plt.title(class_names[tf.math.argmax(predict[0])]+"/"+class_names[tf.math.argmax(labels[i])])
    plt.axis("off")

#predict = model.predict(test_dataset)

#print(predict[0])
#iterator = iter(test_dataset)
#sample = iterator.get_next();

#print(sample[0][0])

plt.show();
# Out:
# Found 8005 files belonging to 2 classes.
# Found 2023 files belonging to 2 classes.
# 2022-07-06 19:51:56.375540: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 96)                49248
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 194
# =================================================================
# Total params: 1,600,418
# Trainable params: 1,600,418
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2022-07-06 19:51:56.942854: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2/2 - 11s - loss: 96.4703 - accuracy: 0.5136 - categorical_crossentropy: 96.4703 - val_loss: 70.0025 - val_accuracy: 0.5002 - val_categorical_crossentropy: 70.0025
# Epoch 2/100
# 2/2 - 9s - loss: 60.9488 - accuracy: 0.4939 - categorical_crossentropy: 60.9488 - val_loss: 20.9748 - val_accuracy: 0.4998 - val_categorical_crossentropy: 20.9748
# Epoch 3/100
# 2/2 - 9s - loss: 17.9100 - accuracy: 0.4997 - categorical_crossentropy: 17.9100 - val_loss: 0.9665 - val_accuracy: 0.4998 - val_categorical_crossentropy: 0.9665
# Epoch 4/100
# 2/2 - 9s - loss: 1.6403 - accuracy: 0.5038 - categorical_crossentropy: 1.6403 - val_loss: 3.8235 - val_accuracy: 0.5002 - val_categorical_crossentropy: 3.8235
# Epoch 5/100
# 2/2 - 9s - loss: 3.4777 - accuracy: 0.5003 - categorical_crossentropy: 3.4777 - val_loss: 0.8791 - val_accuracy: 0.5007 - val_categorical_crossentropy: 0.8791
# Epoch 6/100
# 2/2 - 9s - loss: 1.0946 - accuracy: 0.4977 - categorical_crossentropy: 1.0946 - val_loss: 1.4000 - val_accuracy: 0.4998 - val_categorical_crossentropy: 1.4000
# Epoch 7/100
# 2/2 - 9s - loss: 1.2744 - accuracy: 0.4997 - categorical_crossentropy: 1.2744 - val_loss: 0.7218 - val_accuracy: 0.4988 - val_categorical_crossentropy: 0.7218
# Epoch 8/100
# 2/2 - 9s - loss: 0.7158 - accuracy: 0.4984 - categorical_crossentropy: 0.7158 - val_loss: 0.6885 - val_accuracy: 0.5457 - val_categorical_crossentropy: 0.6885
# Epoch 9/100
# 2/2 - 9s - loss: 0.6859 - accuracy: 0.5467 - categorical_crossentropy: 0.6859 - val_loss: 0.6966 - val_accuracy: 0.5057 - val_categorical_crossentropy: 0.6966
# Epoch 10/100
# 2/2 - 9s - loss: 0.6931 - accuracy: 0.5094 - categorical_crossentropy: 0.6931 - val_loss: 0.6841 - val_accuracy: 0.5472 - val_categorical_crossentropy: 0.6841
# Epoch 11/100
# 2/2 - 9s - loss: 0.6806 - accuracy: 0.5711 - categorical_crossentropy: 0.6806 - val_loss: 0.6739 - val_accuracy: 0.5744 - val_categorical_crossentropy: 0.6739
# Epoch 12/100
# 2/2 - 9s - loss: 0.6692 - accuracy: 0.5898 - categorical_crossentropy: 0.6692 - val_loss: 0.6609 - val_accuracy: 0.6026 - val_categorical_crossentropy: 0.6609
# Epoch 13/100
# 2/2 - 9s - loss: 0.6592 - accuracy: 0.6140 - categorical_crossentropy: 0.6592 - val_loss: 0.6598 - val_accuracy: 0.6031 - val_categorical_crossentropy: 0.6598
# Epoch 14/100
# 2/2 - 9s - loss: 0.6560 - accuracy: 0.6079 - categorical_crossentropy: 0.6560 - val_loss: 0.6570 - val_accuracy: 0.6100 - val_categorical_crossentropy: 0.6570
# Epoch 15/100
# 2/2 - 9s - loss: 0.6510 - accuracy: 0.6250 - categorical_crossentropy: 0.6510 - val_loss: 0.6508 - val_accuracy: 0.6268 - val_categorical_crossentropy: 0.6508
# Epoch 16/100
# 2/2 - 9s - loss: 0.6424 - accuracy: 0.6408 - categorical_crossentropy: 0.6424 - val_loss: 0.6513 - val_accuracy: 0.6130 - val_categorical_crossentropy: 0.6513
# Epoch 17/100
# 2/2 - 9s - loss: 0.6427 - accuracy: 0.6370 - categorical_crossentropy: 0.6427 - val_loss: 0.6471 - val_accuracy: 0.6179 - val_categorical_crossentropy: 0.6471
# Epoch 18/100
# 2/2 - 9s - loss: 0.6393 - accuracy: 0.6304 - categorical_crossentropy: 0.6393 - val_loss: 0.6439 - val_accuracy: 0.6288 - val_categorical_crossentropy: 0.6439
# Epoch 19/100
# 2/2 - 9s - loss: 0.6307 - accuracy: 0.6486 - categorical_crossentropy: 0.6307 - val_loss: 0.6491 - val_accuracy: 0.6115 - val_categorical_crossentropy: 0.6491
# Epoch 20/100
# 2/2 - 9s - loss: 0.6371 - accuracy: 0.6276 - categorical_crossentropy: 0.6371 - val_loss: 0.6395 - val_accuracy: 0.6337 - val_categorical_crossentropy: 0.6395
# Epoch 21/100
# 2/2 - 9s - loss: 0.6301 - accuracy: 0.6423 - categorical_crossentropy: 0.6301 - val_loss: 0.6544 - val_accuracy: 0.6159 - val_categorical_crossentropy: 0.6544
# Epoch 22/100
# 2/2 - 9s - loss: 0.6351 - accuracy: 0.6256 - categorical_crossentropy: 0.6351 - val_loss: 0.6466 - val_accuracy: 0.6214 - val_categorical_crossentropy: 0.6466
# Epoch 23/100
# 2/2 - 9s - loss: 0.6286 - accuracy: 0.6423 - categorical_crossentropy: 0.6286 - val_loss: 0.6442 - val_accuracy: 0.6357 - val_categorical_crossentropy: 0.6442
# Epoch 24/100
# 2/2 - 9s - loss: 0.6242 - accuracy: 0.6471 - categorical_crossentropy: 0.6242 - val_loss: 0.6350 - val_accuracy: 0.6411 - val_categorical_crossentropy: 0.6350
# Epoch 25/100
# 2/2 - 9s - loss: 0.6162 - accuracy: 0.6558 - categorical_crossentropy: 0.6162 - val_loss: 0.6327 - val_accuracy: 0.6480 - val_categorical_crossentropy: 0.6327
# Epoch 26/100
# 2/2 - 9s - loss: 0.6125 - accuracy: 0.6653 - categorical_crossentropy: 0.6125 - val_loss: 0.6304 - val_accuracy: 0.6485 - val_categorical_crossentropy: 0.6304
# Epoch 27/100
# 2/2 - 9s - loss: 0.6090 - accuracy: 0.6658 - categorical_crossentropy: 0.6090 - val_loss: 0.6309 - val_accuracy: 0.6505 - val_categorical_crossentropy: 0.6309
# Epoch 28/100
# 2/2 - 9s - loss: 0.6056 - accuracy: 0.6721 - categorical_crossentropy: 0.6056 - val_loss: 0.6273 - val_accuracy: 0.6431 - val_categorical_crossentropy: 0.6273
# Epoch 29/100
# 2/2 - 9s - loss: 0.5991 - accuracy: 0.6758 - categorical_crossentropy: 0.5991 - val_loss: 0.6260 - val_accuracy: 0.6505 - val_categorical_crossentropy: 0.6260
# Epoch 30/100
# 2/2 - 9s - loss: 0.5946 - accuracy: 0.6792 - categorical_crossentropy: 0.5946 - val_loss: 0.6228 - val_accuracy: 0.6515 - val_categorical_crossentropy: 0.6228
# Epoch 31/100
# 2/2 - 9s - loss: 0.5909 - accuracy: 0.6837 - categorical_crossentropy: 0.5909 - val_loss: 0.6316 - val_accuracy: 0.6476 - val_categorical_crossentropy: 0.6316
# Epoch 32/100
# 2/2 - 9s - loss: 0.5946 - accuracy: 0.6750 - categorical_crossentropy: 0.5946 - val_loss: 0.6201 - val_accuracy: 0.6525 - val_categorical_crossentropy: 0.6201
# Epoch 33/100
# 2/2 - 9s - loss: 0.5814 - accuracy: 0.6929 - categorical_crossentropy: 0.5814 - val_loss: 0.6316 - val_accuracy: 0.6540 - val_categorical_crossentropy: 0.6316
# Epoch 34/100
# 2/2 - 9s - loss: 0.5848 - accuracy: 0.6912 - categorical_crossentropy: 0.5848 - val_loss: 0.6187 - val_accuracy: 0.6624 - val_categorical_crossentropy: 0.6187
# Epoch 35/100
# 2/2 - 9s - loss: 0.5748 - accuracy: 0.6921 - categorical_crossentropy: 0.5748 - val_loss: 0.6058 - val_accuracy: 0.6733 - val_categorical_crossentropy: 0.6058
# Epoch 36/100
# 2/2 - 9s - loss: 0.5625 - accuracy: 0.7093 - categorical_crossentropy: 0.5625 - val_loss: 0.6050 - val_accuracy: 0.6782 - val_categorical_crossentropy: 0.6050
# Epoch 37/100
# 2/2 - 9s - loss: 0.5541 - accuracy: 0.7181 - categorical_crossentropy: 0.5541 - val_loss: 0.6125 - val_accuracy: 0.6658 - val_categorical_crossentropy: 0.6125
# Epoch 38/100
# 2/2 - 9s - loss: 0.5751 - accuracy: 0.6912 - categorical_crossentropy: 0.5751 - val_loss: 0.6819 - val_accuracy: 0.6184 - val_categorical_crossentropy: 0.6819
# Epoch 39/100
# 2/2 - 9s - loss: 0.6182 - accuracy: 0.6531 - categorical_crossentropy: 0.6182 - val_loss: 0.6308 - val_accuracy: 0.6490 - val_categorical_crossentropy: 0.6308
# Epoch 40/100
# 2/2 - 9s - loss: 0.5690 - accuracy: 0.6958 - categorical_crossentropy: 0.5690 - val_loss: 0.6294 - val_accuracy: 0.6530 - val_categorical_crossentropy: 0.6294
# Epoch 41/100
# 2/2 - 9s - loss: 0.5644 - accuracy: 0.7032 - categorical_crossentropy: 0.5644 - val_loss: 0.6269 - val_accuracy: 0.6485 - val_categorical_crossentropy: 0.6269
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
